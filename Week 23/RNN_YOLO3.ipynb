# %% [markdown]
# # Introduction
# Run the implementation of Faster R-CNN [1].
#
#
# [1] Ren, S., He, K., Girshick, R., Sun, J .: Faster r-cnn: Towards real-time object detection with region proposal networks. In: Advances in neural information processing systems. (2015 ) 91–99
#
#
# https://arxiv.org/pdf/1506.01497.pdf
#
#
# Please use the following. It is an implementation using Keras.
#
#
# duckrabbits / ObjectDetection at master

# %% [markdown]
# # Problem 1
# Please refer to the README to run the above implementation.

# %% [markdown]
# ## Summary of implementation
#
# ### Installation
# Required version of python, keras and tensorflow was not mentioned
# - I had to did manual luck install to find out
# - Keras 2.3
# - Python any
# - Tensorflow 1.5
# - and opencv-python
# - h5py (cause the prediction code had some error) -> had to watch mentor session for this 💢

# %% [markdown]
# ## Training
# I'll just put some of the output from my run session here
# ```
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 4, 4)         0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 4, 14, 14, 10 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 4, 7, 7, 512) 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 7, 7, 512) 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 4, 7, 7, 512) 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 4, 7, 7, 2048 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 4, 7, 7, 2048 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 7, 7, 2048 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 7, 7, 2048 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 4, 7, 7, 512) 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 7, 7, 512) 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 7, 7, 512) 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 7, 7, 2048 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 7, 7, 2048 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 4, 7, 7, 512) 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 7, 7, 512) 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 7, 7, 512) 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 7, 7, 2048 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 7, 7, 2048 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 4, 1, 1, 2048 0           activation_49[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 4, 2048)      0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 1 6156        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 4 24624       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_19 (TimeDistributed (None, 4, 19)        38931       time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_19 (TimeDistribut (None, 4, 72)        147528      time_distributed_1[0][0]
# ==================================================================================================
# Total params: 28,524,055
# Trainable params: 28,417,815
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# Epoch 1/10
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-10-21 22:42:58.598429: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-10-21 22:42:58.610900: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7feb97eb7260 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-21 22:42:58.610915: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  8/10 [=======================>......] - ETA: 7s - rpn_cls: 5.4148 - rpn_regr: 0.1485 - detector_cls: 6.3959 - detector_regr: 2.4842 Exception: 'NoneType' object is not subscriptable
# 10/10 [==============================] - 34s 3s/step - rpn_cls: 5.1672 - rpn_regr: 0.1625 - detector_cls: 6.6279 - detector_regr: 2.6679
# Average number of overlapping bounding boxes from RPN = 17.3 for 10 previous iterations
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 16.636363636363637
# Classifier accuracy for bounding boxes from RPN: 0.425
# Loss RPN classifier: 4.155173597112919
# Loss RPN regression: 0.21548169292509556
# Loss Detector classifier: 7.582251167297363
# Loss Detector regression: 3.2492324084043505
# Elapsed time: 35.61510920524597[s]
# Total loss decreased from inf to 15.202138865739727, saving weights
# Epoch 2/10
#  9/10 [==========================>...] - ETA: 1s - rpn_cls: 2.0071 - rpn_regr: 0.1778 - detector_cls: 6.8371 - detector_regr: 2.6254Average number of overlapping bounding boxes from RPN = 19.1 for 10 previous iterations
# 10/10 [==============================] - 17s 2s/step - rpn_cls: 1.8969 - rpn_regr: 0.1735 - detector_cls: 6.6473 - detector_regr: 2.5517
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.818181818181817
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 0.9052442316992859
# Loss RPN regression: 0.13436158057302236
# Loss Detector classifier: 4.938996005058288
# Loss Detector regression: 1.8884747534990312
# Elapsed time: 49.438190937042236[s]
# Total loss decreased from 15.202138865739727 to 7.867076570829628, saving weights
# Epoch 3/10
#  8/10 [=======================>......] - ETA: 3s - rpn_cls: 2.3490 - rpn_regr: 0.1882 - detector_cls: 2.1655 - detector_regr: 0.3931Average number of overlapping bounding boxes from RPN = 18.9 for 10 previous iterations
# 10/10 [==============================] - 16s 2s/step - rpn_cls: 2.3814 - rpn_regr: 0.1802 - detector_cls: 2.1955 - detector_regr: 0.4213
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.818181818181817
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.3787881766445933
# Loss RPN regression: 0.14258830435574055
# Loss Detector classifier: 2.3315866351127625
# Loss Detector regression: 0.5243351504206657
# Elapsed time: 17.820646047592163[s]
# Total loss decreased from 7.867076570829628 to 5.377298266533763, saving weights
# Epoch 4/10
#  7/10 [====================>.........] - ETA: 4s - rpn_cls: 1.9381 - rpn_regr: 0.0804 - detector_cls: 2.1451 - detector_regr: 0.4836Average number of overlapping bounding boxes from RPN = 21.8 for 10 previous iterations
# 10/10 [==============================] - 16s 2s/step - rpn_cls: 1.9805 - rpn_regr: 0.0872 - detector_cls: 2.1401 - detector_regr: 0.5201
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.545454545454547
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 1.945772424099232
# Loss RPN regression: 0.09988912399858237
# Loss Detector classifier: 2.120077896118164
# Loss Detector regression: 0.5926942676305771
# Elapsed time: 18.035290241241455[s]
# Total loss decreased from 5.377298266533763 to 4.758433711846555, saving weights
# Epoch 5/10
#  6/10 [=================>............] - ETA: 6s - rpn_cls: 1.4044 - rpn_regr: 0.1291 - detector_cls: 2.3189 - detector_regr: 0.4277Average number of overlapping bounding boxes from RPN = 19.0 for 10 previous iterations
# 10/10 [==============================] - 16s 2s/step - rpn_cls: 1.6851 - rpn_regr: 0.1171 - detector_cls: 2.2783 - detector_regr: 0.4728
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.181818181818183
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 1.7589249591612315
# Loss RPN regression: 0.10308794537559152
# Loss Detector classifier: 2.197615683078766
# Loss Detector regression: 0.592256098985672
# Elapsed time: 18.39523410797119[s]
# Total loss decreased from 4.758433711846555 to 4.651884686601261, saving weights
# Epoch 6/10
#  5/10 [==============>...............] - ETA: 7s - rpn_cls: 3.6987 - rpn_regr: 0.0823 - detector_cls: 2.2432 - detector_regr: 0.4778Average number of overlapping bounding boxes from RPN = 19.9 for 10 previous iterations
# 10/10 [==============================] - 16s 2s/step - rpn_cls: 3.2340 - rpn_regr: 0.0879 - detector_cls: 2.1468 - detector_regr: 0.5433
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.0
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.6011019712430423
# Loss RPN regression: 0.09072768203914165
# Loss Detector classifier: 2.0391798973083497
# Loss Detector regression: 0.636567585170269
# Elapsed time: 17.97484517097473[s]
# Epoch 7/10
#  4/10 [===========>..................] - ETA: 9s - rpn_cls: 1.4169 - rpn_regr: 0.0643 - detector_cls: 1.8676 - detector_regr: 0.4400 Average number of overlapping bounding boxes from RPN = 18.2 for 10 previous iterations
# 10/10 [==============================] - 16s 2s/step - rpn_cls: 2.2932 - rpn_regr: 0.0966 - detector_cls: 1.9269 - detector_regr: 0.4342
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 10.545454545454545
# Classifier accuracy for bounding boxes from RPN: 0.6
# Loss RPN classifier: 3.223811376694357
# Loss RPN regression: 0.13516187891364098
# Loss Detector classifier: 1.9888691186904908
# Loss Detector regression: 0.42487615495920183
# Elapsed time: 18.120811939239502[s]
# Epoch 8/10
#  3/10 [========>.....................] - ETA: 11s - rpn_cls: 2.3907 - rpn_regr: 0.0781 - detector_cls: 1.7325 - detector_regr: 0.5190Average number of overlapping bounding boxes from RPN = 7.9 for 10 previous iterations
# 10/10 [==============================] - 17s 2s/step - rpn_cls: 2.9759 - rpn_regr: 0.0874 - detector_cls: 1.6226 - detector_regr: 0.4489
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 12.545454545454545
# Classifier accuracy for bounding boxes from RPN: 0.65
# Loss RPN classifier: 2.195338362205039
# Loss RPN regression: 0.08247942551970482
# Loss Detector classifier: 1.88691603243351
# Loss Detector regression: 0.5239593714475632
# Elapsed time: 18.444491147994995[s]
# Epoch 9/10
#  2/10 [=====>........................] - ETA: 12s - rpn_cls: 0.0011 - rpn_regr: 0.1304 - detector_cls: 1.8106 - detector_regr: 0.6033    Average number of overlapping bounding boxes from RPN = 13.3 for 10 previous iterations
# 10/10 [==============================] - 16s 2s/step - rpn_cls: 1.5854 - rpn_regr: 0.1200 - detector_cls: 2.0837 - detector_regr: 0.6180
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.090909090909092
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.072207595581858
# Loss RPN regression: 0.1086198290809989
# Loss Detector classifier: 2.2218319535255433
# Loss Detector regression: 0.6006830602884292
# Elapsed time: 17.74801993370056[s]
# Epoch 10/10
#  1/10 [==>...........................] - ETA: 13s - rpn_cls: 1.9685 - rpn_regr: 0.0257 - detector_cls: 2.7481 - detector_regr: 0.4842Average number of overlapping bounding boxes from RPN = 10.9 for 10 previous iterations
# 10/10 [==============================] - 16s 2s/step - rpn_cls: 2.2906 - rpn_regr: 0.0597 - detector_cls: 2.2877 - detector_regr: 0.4590
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.0
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.2543277284290526
# Loss RPN regression: 0.08730439506471158
# Loss Detector classifier: 2.146378993988037
# Loss Detector regression: 0.4597975164651871
# Elapsed time: 17.807032108306885[s]
# training is done
# -------------------------------
# path to config file : ./save/train_20211021-224238_config.pickle
# ```

# %% [markdown]
# ## Predicting
# ```
#  $ python predict.py -i "./kaggle_simpson_testset" -c "./save/train_20211021-224238_config.pickle"
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /Users/long.th/Documents/DiveIntoCode/Week 23/ObjectDetection/model/RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-10-21 22:49:38.517445: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-10-21 22:49:38.531118: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7faced4e0260 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-10-21 22:49:38.531164: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# abraham_grampa_simpson_0.jpg
# []
# Elapsed time = 2.927870035171509[s]
# abraham_grampa_simpson_1.jpg
# []
# Elapsed time = 1.7712349891662598[s]
# abraham_grampa_simpson_10.jpg
# []
# Elapsed time = 1.807798147201538[s]
# abraham_grampa_simpson_11.jpg
# []
# Elapsed time = 1.7968699932098389[s]
# abraham_grampa_simpson_12.jpg
# []
# Elapsed time = 1.7912988662719727[s]
# abraham_grampa_simpson_13.jpg
# []
# Elapsed time = 1.8412861824035645[s]
# abraham_grampa_simpson_14.jpg
# []
# Elapsed time = 1.8106141090393066[s]
# abraham_grampa_simpson_15.jpg
# []
# Elapsed time = 1.8365058898925781[s]
# abraham_grampa_simpson_16.jpg
# []
# Elapsed time = 1.7901971340179443[s]
# abraham_grampa_simpson_17.jpg
# []
# Elapsed time = 2.012974977493286[s]
# abraham_grampa_simpson_18.jpg
# []
# Elapsed time = 2.0532968044281006[s]
# abraham_grampa_simpson_19.jpg
# []
# Elapsed time = 1.8502721786499023[s]
# abraham_grampa_simpson_2.jpg
# []
# Elapsed time = 2.0102059841156006[s]
# abraham_grampa_simpson_20.jpg
# []
# Elapsed time = 1.972541093826294[s]
# abraham_grampa_simpson_21.jpg
# []
# Elapsed time = 1.9470326900482178[s]
# abraham_grampa_simpson_22.jpg
# []
# Elapsed time = 1.827085018157959[s]
# abraham_grampa_simpson_23.jpg
# []
# Elapsed time = 1.9521050453186035[s]
# abraham_grampa_simpson_24.jpg
# []
# Elapsed time = 1.8841919898986816[s]
# abraham_grampa_simpson_25.jpg
# []
# Elapsed time = 2.037122964859009[s]
# abraham_grampa_simpson_26.jpg
# []
# Elapsed time = 2.457180976867676[s]
# abraham_grampa_simpson_27.jpg
# []
# Elapsed time = 2.300067186355591[s]
# abraham_grampa_simpson_28.jpg
# []
# Elapsed time = 1.8997223377227783[s]
# abraham_grampa_simpson_29.jpg
# []
# Elapsed time = 1.8919098377227783[s]
# abraham_grampa_simpson_3.jpg
# []
# Elapsed time = 1.778311014175415[s]
# abraham_grampa_simpson_30.jpg
# []
# Elapsed time = 1.8288261890411377[s]
# abraham_grampa_simpson_31.jpg
# []
# Elapsed time = 1.8796532154083252[s]
# abraham_grampa_simpson_32.jpg
# []
# Elapsed time = 1.8322129249572754[s]
# abraham_grampa_simpson_33.jpg
# []
# Elapsed time = 2.227414846420288[s]
# abraham_grampa_simpson_34.jpg
# []
# Elapsed time = 2.3956527709960938[s]
# abraham_grampa_simpson_35.jpg
# []
# Elapsed time = 2.275753974914551[s]
# abraham_grampa_simpson_36.jpg
# []
# Elapsed time = 2.2773852348327637[s]
# abraham_grampa_simpson_37.jpg
# []
# Elapsed time = 2.046255111694336[s]
# abraham_grampa_simpson_38.jpg
# []
# Elapsed time = 2.1009538173675537[s]
# abraham_grampa_simpson_39.jpg
# []
# Elapsed time = 2.069840908050537[s]
# abraham_grampa_simpson_4.jpg
# []
# Elapsed time = 2.024134874343872[s]
# abraham_grampa_simpson_40.jpg
# []
# Elapsed time = 2.2451817989349365[s]
# abraham_grampa_simpson_41.jpg
# []
# Elapsed time = 2.4615349769592285[s]
# abraham_grampa_simpson_42.jpg
# []
# Elapsed time = 2.4475290775299072[s]
# abraham_grampa_simpson_43.jpg
# []
# Elapsed time = 2.4030869007110596[s]
# abraham_grampa_simpson_44.jpg
# []
# Elapsed time = 2.161139965057373[s]
# abraham_grampa_simpson_45.jpg
# []
# Elapsed time = 2.2208361625671387[s]
# abraham_grampa_simpson_46.jpg
# []
# Elapsed time = 2.460461139678955[s]
# abraham_grampa_simpson_47.jpg
# []
# Elapsed time = 2.3495090007781982[s]
# abraham_grampa_simpson_48.jpg
# []
# Elapsed time = 2.0616159439086914[s]
# abraham_grampa_simpson_49.jpg
# []
# Elapsed time = 1.9711627960205078[s]
# abraham_grampa_simpson_7.jpg
# []
# Elapsed time = 2.009168863296509[s]
# abraham_grampa_simpson_8.jpg
# []
# Elapsed time = 2.0958409309387207[s]
# abraham_grampa_simpson_9.jpg
# []
# Elapsed time = 2.0369770526885986[s]
# apu_nahasapeemapetilon_0.jpg
# []
# Elapsed time = 2.0750198364257812[s]
# apu_nahasapeemapetilon_1.jpg
# []
# Elapsed time = 2.4034080505371094[s]
# apu_nahasapeemapetilon_10.jpg
# []
# Elapsed time = 2.3193109035491943[s]
# apu_nahasapeemapetilon_11.jpg
# []
# Elapsed time = 2.256119966506958[s]
# apu_nahasapeemapetilon_12.jpg
# []
# Elapsed time = 2.0180649757385254[s]
# apu_nahasapeemapetilon_13.jpg
# []
# Elapsed time = 2.008852005004883[s]
# apu_nahasapeemapetilon_14.jpg
# []
# Elapsed time = 2.1950128078460693[s]
# apu_nahasapeemapetilon_15.jpg
# []
# Elapsed time = 2.187335252761841[s]
# apu_nahasapeemapetilon_16.jpg
# []
# Elapsed time = 2.1535592079162598[s]
# apu_nahasapeemapetilon_17.jpg
# []
# Elapsed time = 2.0590531826019287[s]
# apu_nahasapeemapetilon_18.jpg
# []
# Elapsed time = 1.941486120223999[s]
# apu_nahasapeemapetilon_19.jpg
# []
# Elapsed time = 2.0422921180725098[s]
# apu_nahasapeemapetilon_2.jpg
# []
# Elapsed time = 2.1935207843780518[s]
# apu_nahasapeemapetilon_20.jpg
# []
# Elapsed time = 2.3645591735839844[s]
# apu_nahasapeemapetilon_21.jpg
# []
# Elapsed time = 2.587070941925049[s]
# apu_nahasapeemapetilon_22.jpg
# []
# Elapsed time = 2.5993101596832275[s]
# apu_nahasapeemapetilon_23.jpg
# []
# Elapsed time = 2.391087055206299[s]
# apu_nahasapeemapetilon_24.jpg
# []
# Elapsed time = 2.0575249195098877[s]
# apu_nahasapeemapetilon_25.jpg
# []
# Elapsed time = 2.3349697589874268[s]
# apu_nahasapeemapetilon_26.jpg
# []
# Elapsed time = 2.1422629356384277[s]
# apu_nahasapeemapetilon_27.jpg
# []
# Elapsed time = 2.0769917964935303[s]
# apu_nahasapeemapetilon_28.jpg
# []
# Elapsed time = 2.0669658184051514[s]
# apu_nahasapeemapetilon_29.jpg
# []
# Elapsed time = 1.990617036819458[s]
# apu_nahasapeemapetilon_3.jpg
# []
# Elapsed time = 2.0563578605651855[s]
# apu_nahasapeemapetilon_30.jpg
# []
# Elapsed time = 2.091992139816284[s]
# apu_nahasapeemapetilon_31.jpg
# []
# Elapsed time = 1.9496328830718994[s]
# apu_nahasapeemapetilon_32.jpg
# []
# Elapsed time = 2.2017080783843994[s]
# apu_nahasapeemapetilon_33.jpg
# []
# Elapsed time = 1.9419970512390137[s]
# apu_nahasapeemapetilon_34.jpg
# []
# Elapsed time = 2.2194859981536865[s]
# apu_nahasapeemapetilon_35.jpg
# []
# Elapsed time = 2.1690878868103027[s]
# apu_nahasapeemapetilon_36.jpg
# []
# Elapsed time = 2.129415273666382[s]
# apu_nahasapeemapetilon_37.jpg
# []
# Elapsed time = 2.1169910430908203[s]
# apu_nahasapeemapetilon_38.jpg
# []
# Elapsed time = 2.5834150314331055[s]
# apu_nahasapeemapetilon_39.jpg
# []
# Elapsed time = 2.409512996673584[s]
# apu_nahasapeemapetilon_4.jpg
# []
# Elapsed time = 2.3326799869537354[s]
# apu_nahasapeemapetilon_40.jpg
# []
# Elapsed time = 2.192070960998535[s]
# apu_nahasapeemapetilon_41.jpg
# []
# Elapsed time = 2.4789140224456787[s]
# apu_nahasapeemapetilon_42.jpg
# []
# Elapsed time = 2.06648588180542[s]
# apu_nahasapeemapetilon_43.jpg
# []
# Elapsed time = 2.276309013366699[s]
# apu_nahasapeemapetilon_44.jpg
# []
# Elapsed time = 2.182961940765381[s]
# apu_nahasapeemapetilon_45.jpg
# []
# Elapsed time = 2.1521079540252686[s]
# apu_nahasapeemapetilon_46.jpg
# []
# Elapsed time = 2.257422924041748[s]
# apu_nahasapeemapetilon_47.jpg
# []
# Elapsed time = 2.31404185295105[s]
# apu_nahasapeemapetilon_48.jpg
# []
# Elapsed time = 2.466287136077881[s]
# apu_nahasapeemapetilon_49.jpg
# []
# Elapsed time = 2.392132043838501[s]
# apu_nahasapeemapetilon_5.jpg
# []
# Elapsed time = 2.0661973953
# ```

# %% [markdown]
# # Problem 2
# Code Reading

# %% [markdown]
# ### Important parts of Faster R-CNN
# - RPN: function rpn inside file resnet.py
# - Faster R-CNN: faster_rcnn.rb
# - Polling ROI: RoiPoolingConv.py with helper roi_helpers.py
#   - ROI is implemented py sub-classing layer from keras

# %% [markdown]
# # Problem 3
# Estimation by learned weight

# %% [markdown]
# ### Here's the output for 3 images that i tested using downloaded weight
# ![Output Images](init_output.png "Title")

# %% [markdown]
# ### Here's some terminal snippets
#
# ```
# model_data/yolo.h5 model, anchors, and classes loaded.
# WARNING:tensorflow:From /Users/long.th/.pyenv/versions/test/lib/python3.6/site-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# (416, 416, 3)
# 2021-10-23 21:52:16.131210: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-10-23 21:52:16.617934: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# Found 1 boxes for img
# person 0.97 (169, 51) (198, 114)
# 2.716971478002961
# (416, 416, 3)
# Found 0 boxes for img
# 0.3770539130055113
# (416, 416, 3)
# Found 1 boxes for img
# person 0.36 (42, 3) (96, 154)
# 0.45194406500377227
# ```

# %% [markdown]
# # Problem 4
# Create file for learning

# %% [markdown]
# ### What need to be done
# - Create initial weights by running:
#   - `python convert.py -w yolov3.cfg yolov3.weights model_data/yolo_weights.h5`
# - Annotation file must be named `train.txt`
# - Format for each row is `<image-path> x_min,y_min,x_max,y_max,class_id`
#   - Ex: `path/to/img2.jpg 120,300,250,600,2`

# %% [markdown]
# ### What i did for the annotation file
# 1. I included the training folder here: `./simpsons_dataset`
# 2. Copy the annotation file included in the dataset over and rename it `./train.txt`
# 3. Modify the annotation file:
#   - Init row format was ex `./characters/abraham_grampa_simpson/pic_0000.jpg,57,72,52,72,abraham_grampa_simpson`
#   - After modification was ex `./simpsons_dataset/abraham_grampa_simpson/pic_0000.jpg 57,72,52,72,0`
#   - I added a space between the file path and other indexes and also rename classes from text to number (from 0 -> 11)

# %% [markdown]
# # Problem 5
# Confirming that training can be done

# %% [markdown]
# Here's the terminal output for the first 15 minutes of training on the laptop
# ```
# Epoch 1/50
# 2021-10-23 22:24:31.058862: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-10-23 22:24:31.135168: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-10-23 22:24:31.615643: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] shape_optimizer failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
# 2021-10-23 22:24:31.685929: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:533] remapper failed: Invalid argument: Subshape must have computed start >= end since stride is negative, but is 0 and 2 (computed from start 0 and end 9223372036854775807 over shape with rank 2 and stride-1)
#  44/189 [=====>........................] - ETA: 27:50 - loss: 2655.5813
#  ```
#
#  **Can be seen that epoch started and training is going smoothly.**

# %% [markdown]
# # Problem 6
# Code reading

# %% [markdown]
# **I decided to skip this part** 🙇
